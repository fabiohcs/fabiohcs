# %% [markdown]
# <a href="https://colab.research.google.com/github/fabiohcs/fabiohcs/blob/main/Fun%C3%A7%C3%B5es.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nome = 'goat'
print('Bem-vindo(a)', nome)
# Out:
# Bem-vindo(a) goat

# %%
#declarando a funçao(def)
def msg_welcome():
  print('oi')
  print('tchau')

# %%
#chamando a funçao
msg_welcome()
msg_welcome()
# Out:
# oi
# tchau
# oi
# tchau

# %%
#sinal de + = ,
def bomdia(nome, dia):
  print('Bom dia,' +nome+ '. Hoje é', dia)

# %%
bomdia('Fabio','quinta-feira')
bomdia('Lucas','carnaval')
bomdia('Pedro', '26')
# Out:
# Bom dia,Fabio. Hoje é quinta-feira
# Bom dia,Lucas. Hoje é carnaval
# Bom dia,Pedro. Hoje é 26

# %%
#criar funçao que receba dois números(x,y) e exiba a soma deles.
#especificar as variaveis na entrada.
def soma(x,y):
  print(x+y)

# %%
soma(77,33)
soma(56,344)
soma(1/2,1/8)
soma('Fabio',  'Henrique')
# Out:
# 110
# 400
# 0.625
# FabioHenrique
