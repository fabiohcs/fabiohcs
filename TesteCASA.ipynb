# %% [markdown]
# <a href="https://colab.research.google.com/github/fabiohcs/fabiohcs/blob/main/TesteCASA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
a = np.array([2,4])
b = np.array([-1,3])
c = a + b
print(c)
# Out:
# [1 7]

# %%
# !pip install vectorplot

# %%
import vectorplot.vp as vp

vp.plot2d([a, b, c],["green", "crimson", "black"],[-2,5, 0,8])
